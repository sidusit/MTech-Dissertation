# %%
import pickle as p
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HINDUNILVR = p.load(open("/content/drive/MyDrive/Colab Notebooks/Datasets/Indian/Final/HINDUNILVR_combined_v3.p",'rb'))

# %%
HINDUNILVR.columns
# Out:
# Index(['stock_open', 'stock_high', 'stock_low', 'stock_close',
#        'stock_adjclose_target', 'Volume', 'SMA', 'EMA', 'nifty50_price',
#        'nifty50_open', 'nifty50_high', 'nifty50_low', 'nifty50_Vol.',
#        'nifty50_Chg%', 'niftybank_price', 'niftybank_open', 'niftybank_high',
#        'niftybank_low', 'niftybank_Vol.', 'niftybank_Change %', 'Sales',
#        'Expenses', 'Material Cost', 'Employee Cost', 'Operating Profit', 'OPM',
#        'Other Income', 'Interest', 'Depreciation', 'Profit before tax', 'Tax',
#        'Net Profit', 'EPS in Rs', 'Agriculture, Forestry and Fishing ',
#        'Mining & Quarrying', 'Manufacturing',
#        'Electricity, Gas, Water Supply & Other Utility', 'Construction',
#        'Trade, Hotels, Transport, Communication and Services Related to Broadcasting',
#        'Financial, Real Estate and Professional Services',
#        'Public Administration, Defence and Other Services',
# ...

# %%
HINDUNILVR['target_lag'] = HINDUNILVR['stock_adjclose_target'].shift(-5)

# %%
HINDUNILVR.tail(10)
# Out:
#              stock_open   stock_high  ...  ShPrice_monthly   target_lag
# Date                                  ...
# 2021-11-16  2434.649902  2434.649902  ...         217.3347  2374.750000
# 2021-11-17  2404.000000  2410.050049  ...         217.3347  2349.050049
# 2021-11-18  2390.000000  2406.350098  ...         217.3347  2335.100098
# 2021-11-22  2409.399902  2409.899902  ...         217.3347  2329.399902
# 2021-11-23  2387.800049  2400.000000  ...         217.3347  2317.550049
# 2021-11-24  2406.000000  2406.000000  ...         217.3347          NaN
# 2021-11-25  2387.000000  2387.000000  ...         217.3347          NaN
# 2021-11-26  2344.000000  2365.000000  ...         217.3347          NaN
# 2021-11-29  2334.399902  2342.250000  ...         217.3347          NaN
# 2021-11-30  2322.000000  2361.000000  ...         217.3347          NaN
#
# [10 rows x 56 columns]

# %%
sns.heatmap(HINDUNILVR.corr())

# %%
HINDUNILVR.corr()
# Out:
#                                                     stock_open  ...  target_lag
# stock_open                                            1.000000  ...    0.960707
# stock_high                                            0.995712  ...    0.963603
# stock_low                                             0.996900  ...    0.963450
# stock_close                                           0.993069  ...    0.966745
# stock_adjclose_target                                 0.992648  ...    0.970166
# Volume                                               -0.001209  ...    0.003152
# SMA                                                   0.983113  ...    0.948445
# EMA                                                   0.987069  ...    0.954877
# nifty50_price                                         0.706443  ...    0.709435
# nifty50_open                                          0.706485  ...    0.707609
# nifty50_high                                          0.710029  ...    0.713230
# ...

# %%
corr = HINDUNILVR.corr()

# %%
abs_corr = abs(corr)

# %%
target_corr = abs(HINDUNILVR.corr())['target_lag'].sort_values(ascending=False)

# %%
top_corr = target_corr[target_corr>0.2]

# %%
top_corr
# Out:
# target_lag                                                                      1.000000
# stock_adjclose_target                                                           0.970166
# stock_close                                                                     0.966745
# stock_high                                                                      0.963603
# stock_low                                                                       0.963450
# stock_open                                                                      0.960707
# EMA                                                                             0.954877
# SMA                                                                             0.948445
# CPI Index Previous Month                                                        0.918108
# CPI Index Previous Quarter                                                      0.911586
# ...

# %%
top_corr.index
# Out:
# Index(['target_lag', 'stock_adjclose_target', 'stock_close', 'stock_high',
#        'stock_low', 'stock_open', 'EMA', 'SMA', 'CPI Index Previous Month',
#        'CPI Index Previous Quarter', 'CPI Index', 'CPI Index Previous Year',
#        'Expenses', 'Sales', 'Net Profit', 'ShPrice_monthly', 'nifty50_high',
#        'nifty50_price', 'nifty50_open', 'Operating Profit', 'nifty50_low',
#        'by_High', 'by_Closing_Price', 'by_Open', 'by_Low', 'CPI_monthly_oecd',
#        'Profit before tax', 'EPS in Rs', 'Material Cost', 'Depreciation',
#        'Electricity, Gas, Water Supply & Other Utility', 'niftybank_high',
#        'niftybank_price', 'niftybank_open', 'niftybank_low', 'Employee Cost',
#        'Trade, Hotels, Transport, Communication and Services Related to Broadcasting',
#        'Financial, Real Estate and Professional Services', 'Other Income',
#        'Tax', 'Mining & Quarrying'],
#       dtype='object')

# %%
# HINDUNILVR.to_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/Indian/Final/HINDUNILVR_combined_v3.csv")

# %%
# HINDUNILVR = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Indian/Final/HINDUNILVR_combined_v3.csv')
